# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
E1 = 1000
E2 = 10
k=1
x = np.linspace(1, 1000, 100)
y1 = np.exp(-E1/k/x)
y2 = np.exp(-E2/k/x)

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(["T = "+str(E1), "T = "+str(E2)])
