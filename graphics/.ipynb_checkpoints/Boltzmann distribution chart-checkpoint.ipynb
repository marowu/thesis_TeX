# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
T1 = 1000
T2 = 10
k=1
x = np.linspace(10, 10000, 100)
y1 = np.exp(-x/k/T1)
y2 = np.exp(-x/k/T2)

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(["T = "+str(T1), "T = "+str(T2)])
